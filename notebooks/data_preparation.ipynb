# %%
# importing necessary dependencies
import os
import os.path
os.chdir('..')
from src.read_pitchscapes import *
from src.key_profile import *
import pandas as pd
from pitchscapes.keyfinding import KeyEstimator
os.chdir('notebooks')
import scipy
from sklearn.manifold import Isomap
import unicodedata as ud

# %% [markdown]
# # Pitchscapes, metadata and useful columns
# In this notebook, we prepare the pitch class distributions for training, along with the needed metadata and useful info.

# %%
# Depending on which case we're delaing with, we prepare the paths and composer name for the upcoming work
sample_composers = False
if sample_composers:
    composers = ['Scriabin_Alexander',
                 'Brahms_Johannes', 
                 'Liszt_Franz',
                 'Chopin_Frederic',
                 'Schubert_Franz',
                 'Debussy_Claude',
                 'Ravel_Maurice']
    
    dump_path = 'dump/sample_composers/'
    
else:
    composers = ['Bach_JohannSebastian']
    
    dump_path = 'dump/bach/'

dump_pieces_path = dump_path + 'pieces.csv'
dump_embedding_path = dump_path + 'X_transformed.npy'
dump_landmarks_path = dump_path + 'landmarks.npy'
dump_landmark_labels_path = dump_path + 'landmark_labels.npy'

# %% [markdown]
# **Note** In order to run this cell, the data must be in a data/ folder at the root of the project.
# The dataset is private, but can be obtained from the DCML, our project supervisor is Dr Robert Lieck: robert.lieck@epfl.ch
#
# However, we save the necessary files for the rest of the pipeline in .csv files. Therefore, it's not necessary to obtain the data.

# %%
# For each composer, read the pichscape distributions, we use n_times=10
df_pieces = pd.DataFrame()
for composer in composers:
    pitchscape_folder = read_pitchscapes_in_folder(f'../data/scores/{composer}', 10)
    pitchscape_folder['composer'] = composer
    df_pieces = pd.concat([df_pieces, pitchscape_folder])
# Out:
# reading folder: ../data/scores/Bach_JohannSebastian
#
# reading piece: Bach_BWV_795.musicxml
# reading piece: 227966-Prelude_No._2_BWV_847_in_C_Minor.mxl
# reading piece: 1303106-Fugue_No._11_BWV_880_in_F_Major.mxl
# reading piece: 667506-Prelude_No._19_BWV_864_in_A_Major.mxl
# reading piece: Bach_BWV_772a.musicxml
# reading piece: 971581-Prelude_No._3_BWV_872_in_C_Major.mxl
# reading piece: 609331-Fugue_No._17_BWV_862_in_A_Major.mxl
# reading piece: Brandenburg-Concerto-no.-5-BWV-1050_I-Allegro_Bach-Johann-Sebastian_file1.xml
# reading piece: 571476-Fugue_No._16_BWV_861_in_G_Minor.mxl
# reading piece: 1559631-Fugue_No._16_BWV_885_in_G_Minor.mxl
# reading piece: 1497201-Prelude_No._15_BWV_884_in_G_Major.mxl
# reading piece: 1718101-Fugue_No._19_BWV_888_in_A_Major.mxl
# reading piece: 1141201-Fugue_No._7_BWV_876_in_E_Major.mxl
# reading piece: 869596-Fugue_No._24_BWV_869_in_B_Minor.mxl
# reading piece: 1032401-Prelude_No._4_BWV_873_in_C_Minor.mxl
# reading piece: 936016-Prelude_No._2_BWV_871_in_C_Minor.mxl
# reading piece: Bach_BWV_777.musicxml
# reading piece: 1659556-Fugue_No._18_BWV_887_in_G_Minor.mxl
# reading piece: 1762886-Prelude_No._20_BWV_889_in_A_Minor.mxl
# reading piece: 366016-Prelude_No._9_BWV_854_in_E_Major.mxl
# reading piece: 832636-Fugue_No._23_BWV_868_in_B_Major.mxl
# reading piece: Bach_BWV_790.musicxml
# reading piece: Bach_BWV_793.musicxml
# reading piece: 1777656-Fugue_No._20_BWV_889_in_A_Minor.mxl
# reading piece: Bach_BWV_797.musicxml
# reading piece: 321601-Fugue_No._7_BWV_852_in_E_Major.mxl
# reading piece: Bach_BWV_786.musicxml
# reading piece: 1098286-Prelude_No._6_BWV_875_in_D_Minor.mxl
# reading piece: 1550651-Prelude_No._16_BWV_885_in_G_Minor.mxl
# reading piece: Bach_BWV_780.musicxml
# reading piece: 1040681-Fugue_No._4_BWV_873_in_C_Minor.mxl
# reading piece: 298826-Fugue_No._6_BWV_851_in_D_Minor.mxl
# reading piece: 278266-Fugue_No._5_BWV_850_in_D_Major.mxl
# reading piece: 420466-Prelude_No._11_BWV_856_in_F_Major.mxl
# reading piece: 214901-Fugue_No._1_BWV_846_in_C_Major.mxl
# reading piece: Bach_BWV_799.musicxml
# reading piece: 861731-Prelude_No._24_BWV_869_in_B_Minor.mxl
# reading piece: 770566-Prelude_No._22_BWV_867_in_B_Minor.mxl
# reading piece: 488026-Fugue_No._13_BWV_858_in_F_Major.mxl
# reading piece: Bach_BWV_791.musicxml
# reading piece: 399466-Fugue_No._10_BWV_855_in_E_Minor.mxl
# reading piece: 456166-Fugue_No._12_BWV_857_in_F_Minor.mxl
# reading piece: 742556-Fugue_No._21_BWV_866_in_B_Major.mxl
# reading piece: 700231-Prelude_No._20_BWV_865_in_A_Minor.mxl
# reading piece: 346361-Fugue_No._8_BWV_853_in_D_Minor.mxl
# reading piece: 943546-Fugue_No._2_BWV_871_in_C_Minor.mxl
# reading piece: 641766-Fugue_No._18_BWV_863_in_G_Minor.mxl
# reading piece: 1215101-Fugue_No._9_BWV_878_in_E_Major.mxl
# reading piece: Bach_BWV_775.musicxml
# reading piece: 316381-Prelude_No._7_BWV_852_in_E_Major.mxl
# reading piece: 1066276-Prelude_No._5_BWV_874_in_D_Major.mxl
# reading piece: 978656-Fugue_No._3_BWV_872_in_C_Major.mxl
# reading piece: 897876-Prelude_No._1_BWV_870_in_C_Major.mxl
# reading piece: 426326-Fugue_No._11_BWV_856_in_F_Major.mxl
# reading piece: 511226-Prelude_No._14_BWV_859_in_F_Minor.mxl
# reading piece: Bach_BWV_779.musicxml
# reading piece: 541256-Fugue_No._15_BWV_860_in_G_Major.mxl
# reading piece: 258631-Prelude_No._4_BWV_849_in_C_Minor.mxl
# reading piece: 674796-Fugue_No._19_BWV_864_in_A_Major.mxl
# reading piece: 1392041-Prelude_No._13_BWV_882_in_F_Major.mxl
# reading piece: Bach_BWV_798.musicxml
# reading piece: 210606-Prelude_No._1_BWV_846_in_C_Major.mxl
# reading piece: 516711-Fugue_No._14_BWV_859_in_F_Minor.mxl
# reading piece: 2007701-Fugue_No._24_BWV_893_in_B_Minor.mxl
# reading piece: 1938106-Prelude_No._23_BWV_892_in_B_Major.mxl
# reading piece: 261621-Fugue_No._4_BWV_849_in_C_Minor.mxl
# reading piece: Bach_BWV_784.musicxml
# reading piece: 564461-Prelude_No._16_BWV_861_in_G_Minor.mxl
# reading piece: 1704556-Prelude_No._19_BWV_888_in_A_Major.mxl
# reading piece: 246301-Fugue_No._3_BWV_848_in_C_Major.mxl
# reading piece: 340831-Prelude_No._8_BWV_853_in_E_Minor.mxl
# reading piece: 449286-Prelude_No._12_BWV_857_in_F_Minor.mxl
# reading piece: Bach_BWV_800.musicxml
# reading piece: 535841-Prelude_No._15_BWV_860_in_G_Major.mxl
# reading piece: 1892096-Fugue_No._22_BWV_891_in_B_Minor.mxl
# reading piece: Bach_BWV_787.musicxml
# reading piece: Brandenburg-Concerto-no.-5-BWV-1050_III-Allegro_Bach-Johann-Sebastian_file1.xml
# reading piece: 707191-Fugue_No._20_BWV_865_in_A_Minor.mxl
# reading piece: Bach_BWV_772.musicxml
# reading piece: 242986-Prelude_No._3_BWV_848_in_C_Major.mxl
# reading piece: Brandenburg-Concerto-no.-5-BWV-1050_II-Affettuoso_Bach-Johann-Sebastian_file1.xml
# reading piece: 1293351-Prelude_No._11_BWV_880_in_F_Major.mxl
# reading piece: Bach_BWV_796.musicxml
# reading piece: 1444781-Prelude_No._14_BWV_883_in_F_Minor.mxl
# reading piece: Bach_BWV_801.musicxml
# reading piece: 1951591-Fugue_No._23_BWV_892_in_B_Major.mxl
# reading piece: Bach_BWV_794.musicxml
# reading piece: 1508786-Fugue_No._15_BWV_884_in_G_Major.mxl
# reading piece: 480961-Prelude_No._13_BWV_858_in_F_Major.mxl
# reading piece: 1169116-Prelude_No._8_BWV_877_in_D_Minor.mxl
# reading piece: 1880941-Prelude_No._22_BWV_891_in_B_Minor.mxl
# reading piece: 824336-Prelude_No._23_BWV_868_in_B_Major.mxl
# reading piece: Bach_BWV_773.musicxml
# reading piece: 1647251-Prelude_No._18_BWV_887_in_G_Minor.mxl
# reading piece: 734101-Prelude_No._21_BWV_866_in_B_Major.mxl
# reading piece: Bach_BWV_792.musicxml
# reading piece: 231261-Fugue_No._2_BWV_847_in_C_Minor.mxl
# reading piece: Bach_BWV_789.musicxml
# reading piece: 1402696-Fugue_No._13_BWV_882_in_F_Major.mxl
# reading piece: 1340331-Prelude_No._12_BWV_881_in_F_Minor.mxl
# reading piece: 1133561-Prelude_No._7_BWV_876_in_E_Major.mxl
# reading piece: Bach_BWV_782.musicxml
# reading piece: Bach_BWV_776.musicxml
# reading piece: 393031-Prelude_No._10_BWV_855_in_E_Minor.mxl
# reading piece: 1593551-Prelude_No._17_BWV_886_in_A_Major.mxl
# reading piece: 274576-Prelude_No._5_BWV_850_in_D_Major.mxl
# reading piece: 1603931-Fugue_No._17_BWV_886_in_A_Major.mxl
# reading piece: Bach_BWV_778.musicxml
# reading piece: 1177476-Fugue_No._8_BWV_877_in_D_Minor.mxl
# reading piece: 905966-Fugue_No._1_BWV_870_in_C_Major.mxl
# reading piece: Bach_BWV_788.musicxml
# reading piece: 1994911-Prelude_No._24_BWV_893_in_B_Minor.mxl
# reading piece: 1260556-Fugue_No._10_BWV_879_in_E_Minor.mxl
# reading piece: 1107771-Fugue_No._6_BWV_875_in_D_Minor.mxl
# reading piece: 1350596-Fugue_No._12_BWV_881_in_F_Minor.mxl
# reading piece: 635216-Prelude_No._18_BWV_863_in_G_Minor.mxl
# reading piece: Bach_BWV_774.musicxml
# reading piece: 1073231-Fugue_No._5_BWV_874_in_D_Major.mxl
# reading piece: 294636-Prelude_No._6_BWV_851_in_D_Minor.mxl
# reading piece: 1251606-Prelude_No._10_BWV_879_in_E_Minor.mxl
# reading piece: 371591-Fugue_No._9_BWV_854_in_E_Major.mxl
# reading piece: 1207206-Prelude_No._9_BWV_878_in_E_Major.mxl
# reading piece: 1456381-Fugue_No._14_BWV_883_in_F_Minor.mxl
# reading piece: Bach_BWV_785.musicxml
# reading piece: 778221-Fugue_No._22_BWV_867_in_B_Minor.mxl
# reading piece: Bach_BWV_783.musicxml
# reading piece: 598056-Prelude_No._17_BWV_862_in_A_Major.mxl
# reading piece: 1835741-Fugue_No._21_BWV_890_in_B_Major.mxl
# reading piece: Bach_BWV_781.musicxml
# reading piece: 1822451-Prelude_No._21_BWV_890_in_B_Major.mxl

# %%
df_pieces.head(5)
# Out:
#           C        C#         D        D#         E         F        F#  \
# 0  0.112179  0.067308  0.083333  0.073718  0.086538  0.152244  0.043269
# 1  0.131250  0.069792  0.054167  0.069792  0.097917  0.157292  0.034375
# 2  0.123457  0.076389  0.061728  0.075617  0.085648  0.151235  0.040123
# 3  0.120711  0.078431  0.066176  0.094363  0.075980  0.135417  0.037990
# 4  0.127541  0.076220  0.065041  0.099593  0.072154  0.135671  0.034553
#
#           G        G#         A        A#         B   ts    te  \
# 0  0.068910  0.086538  0.064103  0.092949  0.068910  0.0  14.0
# 1  0.083333  0.087500  0.066667  0.095833  0.052083  0.0  28.0
# 2  0.077160  0.105710  0.055556  0.102623  0.044753  0.0  42.0
# 3  0.089461  0.110294  0.049020  0.100490  0.041667  0.0  56.0
# 4  0.095020  0.105183  0.049797  0.102642  0.036585  0.0  70.0
#
#                     name  piece              composer
# 0  Bach_BWV_795.musicxml      0  Bach_JohannSebastian
# 1  Bach_BWV_795.musicxml      0  Bach_JohannSebastian
# 2  Bach_BWV_795.musicxml      0  Bach_JohannSebastian
# 3  Bach_BWV_795.musicxml      0  Bach_JohannSebastian
# 4  Bach_BWV_795.musicxml      0  Bach_JohannSebastian

# %%
# this is a small detail, there's a difference in the unicode encoding between 
# the metadata file and musicXML filenames, here we deal with that problem
df_pieces['name'] = df_pieces['name'].apply(lambda x: ud.normalize('NFD', str(x)))

# %%
# computing the window width for each data point
df_pieces["window_width"] = df_pieces['te'] - df_pieces['ts']

# %%
df_pieces.head()
# Out:
#           C        C#         D        D#         E         F        F#  \
# 0  0.112179  0.067308  0.083333  0.073718  0.086538  0.152244  0.043269
# 1  0.131250  0.069792  0.054167  0.069792  0.097917  0.157292  0.034375
# 2  0.123457  0.076389  0.061728  0.075617  0.085648  0.151235  0.040123
# 3  0.120711  0.078431  0.066176  0.094363  0.075980  0.135417  0.037990
# 4  0.127541  0.076220  0.065041  0.099593  0.072154  0.135671  0.034553
#
#           G        G#         A        A#         B   ts    te  \
# 0  0.068910  0.086538  0.064103  0.092949  0.068910  0.0  14.0
# 1  0.083333  0.087500  0.066667  0.095833  0.052083  0.0  28.0
# 2  0.077160  0.105710  0.055556  0.102623  0.044753  0.0  42.0
# 3  0.089461  0.110294  0.049020  0.100490  0.041667  0.0  56.0
# 4  0.095020  0.105183  0.049797  0.102642  0.036585  0.0  70.0
#
#                     name  piece              composer  window_width
# 0  Bach_BWV_795.musicxml      0  Bach_JohannSebastian          14.0
# 1  Bach_BWV_795.musicxml      0  Bach_JohannSebastian          28.0
# 2  Bach_BWV_795.musicxml      0  Bach_JohannSebastian          42.0
# 3  Bach_BWV_795.musicxml      0  Bach_JohannSebastian          56.0
# 4  Bach_BWV_795.musicxml      0  Bach_JohannSebastian          70.0

# %%
# computing the relative window width
window_width = (df_pieces['te'] - df_pieces['ts']).to_frame(name='window_width')
window_width['name'] = df_pieces['name']
maxs = window_width.groupby('name')['window_width'].max().rename('max')
mins = window_width.groupby('name')['window_width'].min().rename('min')
maxs_mins = pd.concat([maxs,mins],axis=1)
merged_max_min = df_pieces.merge(maxs_mins, left_on='name', right_index=True)

# %%
maxs_mins.head(5)
# Out:
#                                                  max     min
# name
# 1032401-Prelude_No._4_BWV_873_in_C_Minor.mxl  276.00  27.600
# 1040681-Fugue_No._4_BWV_873_in_C_Minor.mxl    210.75  21.075
# 1066276-Prelude_No._5_BWV_874_in_D_Major.mxl  224.00  22.400
# 1073231-Fugue_No._5_BWV_874_in_D_Major.mxl    199.50  19.950
# 1098286-Prelude_No._6_BWV_875_in_D_Minor.mxl  183.00  18.300

# %%
merged_max_min.head(5)
# Out:
#           C        C#         D        D#         E         F        F#  \
# 0  0.112179  0.067308  0.083333  0.073718  0.086538  0.152244  0.043269
# 1  0.131250  0.069792  0.054167  0.069792  0.097917  0.157292  0.034375
# 2  0.123457  0.076389  0.061728  0.075617  0.085648  0.151235  0.040123
# 3  0.120711  0.078431  0.066176  0.094363  0.075980  0.135417  0.037990
# 4  0.127541  0.076220  0.065041  0.099593  0.072154  0.135671  0.034553
#
#           G        G#         A        A#         B   ts    te  \
# 0  0.068910  0.086538  0.064103  0.092949  0.068910  0.0  14.0
# 1  0.083333  0.087500  0.066667  0.095833  0.052083  0.0  28.0
# 2  0.077160  0.105710  0.055556  0.102623  0.044753  0.0  42.0
# 3  0.089461  0.110294  0.049020  0.100490  0.041667  0.0  56.0
# 4  0.095020  0.105183  0.049797  0.102642  0.036585  0.0  70.0
#
#                     name  piece              composer  window_width    max  \
# 0  Bach_BWV_795.musicxml      0  Bach_JohannSebastian          14.0  140.0
# 1  Bach_BWV_795.musicxml      0  Bach_JohannSebastian          28.0  140.0
# 2  Bach_BWV_795.musicxml      0  Bach_JohannSebastian          42.0  140.0
# 3  Bach_BWV_795.musicxml      0  Bach_JohannSebastian          56.0  140.0
# 4  Bach_BWV_795.musicxml      0  Bach_JohannSebastian          70.0  140.0
#
#     min
# 0  14.0
# 1  14.0
# 2  14.0
# 3  14.0
# 4  14.0

# %%
df_pieces['relative_width'] = (merged_max_min['window_width'] - merged_max_min['min']) \
/ (merged_max_min['max'] - merged_max_min['min'])

# %%
df_pieces.head(5)
# Out:
#           C        C#         D        D#         E         F        F#  \
# 0  0.112179  0.067308  0.083333  0.073718  0.086538  0.152244  0.043269
# 1  0.131250  0.069792  0.054167  0.069792  0.097917  0.157292  0.034375
# 2  0.123457  0.076389  0.061728  0.075617  0.085648  0.151235  0.040123
# 3  0.120711  0.078431  0.066176  0.094363  0.075980  0.135417  0.037990
# 4  0.127541  0.076220  0.065041  0.099593  0.072154  0.135671  0.034553
#
#           G        G#         A        A#         B   ts    te  \
# 0  0.068910  0.086538  0.064103  0.092949  0.068910  0.0  14.0
# 1  0.083333  0.087500  0.066667  0.095833  0.052083  0.0  28.0
# 2  0.077160  0.105710  0.055556  0.102623  0.044753  0.0  42.0
# 3  0.089461  0.110294  0.049020  0.100490  0.041667  0.0  56.0
# 4  0.095020  0.105183  0.049797  0.102642  0.036585  0.0  70.0
#
#                     name  piece              composer  window_width  \
# 0  Bach_BWV_795.musicxml      0  Bach_JohannSebastian          14.0
# 1  Bach_BWV_795.musicxml      0  Bach_JohannSebastian          28.0
# 2  Bach_BWV_795.musicxml      0  Bach_JohannSebastian          42.0
# 3  Bach_BWV_795.musicxml      0  Bach_JohannSebastian          56.0
# 4  Bach_BWV_795.musicxml      0  Bach_JohannSebastian          70.0
#
#    relative_width
# 0        0.000000
# 1        0.111111
# 2        0.222222
# 3        0.333333
# 4        0.444444

# %%
# getting the assignement to tonality and transpositions found by the Key estimator
data_pts = get_pitchscapes_as_np_array(df_pieces)
key_estim = KeyEstimator()
best_match = key_estim.get_estimate(data_pts)

# %%
# adding the major_minor estimate
df_pieces["tonality"] = pd.Series(best_match[:,0])
df_pieces["tonality"] = df_pieces["tonality"].apply(lambda r: "major" if r == 0 else "minor")

# %%
# adding transposition
df_pieces["transposition"] = pd.Series(best_match[:, 1])
mapping_transpo = ['C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B']
df_pieces["transposition"] = df_pieces["transposition"].apply(lambda r: mapping_transpo[r])

# %%
df_pieces.head(5)
# Out:
#           C        C#         D        D#         E         F        F#  \
# 0  0.112179  0.067308  0.083333  0.073718  0.086538  0.152244  0.043269
# 1  0.131250  0.069792  0.054167  0.069792  0.097917  0.157292  0.034375
# 2  0.123457  0.076389  0.061728  0.075617  0.085648  0.151235  0.040123
# 3  0.120711  0.078431  0.066176  0.094363  0.075980  0.135417  0.037990
# 4  0.127541  0.076220  0.065041  0.099593  0.072154  0.135671  0.034553
#
#           G        G#         A  ...         B   ts    te  \
# 0  0.068910  0.086538  0.064103  ...  0.068910  0.0  14.0
# 1  0.083333  0.087500  0.066667  ...  0.052083  0.0  28.0
# 2  0.077160  0.105710  0.055556  ...  0.044753  0.0  42.0
# 3  0.089461  0.110294  0.049020  ...  0.041667  0.0  56.0
# 4  0.095020  0.105183  0.049797  ...  0.036585  0.0  70.0
#
#                     name piece              composer window_width  \
# 0  Bach_BWV_795.musicxml     0  Bach_JohannSebastian         14.0
# 1  Bach_BWV_795.musicxml     0  Bach_JohannSebastian         28.0
# 2  Bach_BWV_795.musicxml     0  Bach_JohannSebastian         42.0
# 3  Bach_BWV_795.musicxml     0  Bach_JohannSebastian         56.0
# 4  Bach_BWV_795.musicxml     0  Bach_JohannSebastian         70.0
#
#    relative_width  tonality transposition
# 0        0.000000     minor             F
# 1        0.111111     minor             F
# 2        0.222222     minor             F
# 3        0.333333     minor             F
# 4        0.444444     minor             F
#
# [5 rows x 21 columns]

# %%
# loading the metadata dataframe
metadata_df = pd.read_csv("../data/metadata.csv", sep="	")
metadata_df = metadata_df[["composer", "composer_first", "filename", "display_year"]]
metadata_df['filename'] = metadata_df['filename'].apply(lambda x: ud.normalize('NFD', str(x)))
metadata_df = metadata_df.rename(columns={"composer": "composer_last"})

# %%
metadata_df.head(5)
# Out:
#   composer_last    composer_first  \
# 0         Alkan  Charles Valentin
# 1         Alkan  Charles Valentin
# 2         Alkan  Charles Valentin
# 3         Alkan  Charles Valentin
# 4         Alkan  Charles Valentin
#
#                                             filename  display_year
# 0  Un_Morceau_Opus_15_No._1__in_A_Minor_Aime-moi.mxl        1837.0
# 1    Un_Morceau_Opus_15_No._2_in_B_Minor_Le_Vent.mxl        1837.0
# 2      Un_Morceau_Opus_15_No._3_in_E_Minor_Morte.mxl        1837.0
# 3     Etude_de_Bravoure_Opus_16_No._3_in_B_Minor.mxl        1837.0
# 4   Etude_de_Concert_pour_Piano_Le_Preux_Opus_17.mxl        1844.0

# %%
# merging the two dataframe 
pieces_final = df_pieces.merge(metadata_df, left_on="name", right_on="filename", how='inner').drop("name", axis=1)

# %%
# sanity check
pieces_final.isnull().any(None)
# Out:
# False

# %%
pieces_final.head(5)
# Out:
#           C        C#         D        D#         E         F        F#  \
# 0  0.112179  0.067308  0.083333  0.073718  0.086538  0.152244  0.043269
# 1  0.131250  0.069792  0.054167  0.069792  0.097917  0.157292  0.034375
# 2  0.123457  0.076389  0.061728  0.075617  0.085648  0.151235  0.040123
# 3  0.120711  0.078431  0.066176  0.094363  0.075980  0.135417  0.037990
# 4  0.127541  0.076220  0.065041  0.099593  0.072154  0.135671  0.034553
#
#           G        G#         A  ...  piece              composer  \
# 0  0.068910  0.086538  0.064103  ...      0  Bach_JohannSebastian
# 1  0.083333  0.087500  0.066667  ...      0  Bach_JohannSebastian
# 2  0.077160  0.105710  0.055556  ...      0  Bach_JohannSebastian
# 3  0.089461  0.110294  0.049020  ...      0  Bach_JohannSebastian
# 4  0.095020  0.105183  0.049797  ...      0  Bach_JohannSebastian
#
#    window_width  relative_width  tonality transposition  composer_last  \
# 0          14.0        0.000000     minor             F           Bach
# 1          28.0        0.111111     minor             F           Bach
# 2          42.0        0.222222     minor             F           Bach
# 3          56.0        0.333333     minor             F           Bach
# 4          70.0        0.444444     minor             F           Bach
#
#      composer_first               filename display_year
# 0  Johann Sebastian  Bach_BWV_795.musicxml       1723.0
# 1  Johann Sebastian  Bach_BWV_795.musicxml       1723.0
# 2  Johann Sebastian  Bach_BWV_795.musicxml       1723.0
# 3  Johann Sebastian  Bach_BWV_795.musicxml       1723.0
# 4  Johann Sebastian  Bach_BWV_795.musicxml       1723.0
#
# [5 rows x 24 columns]

# %%
# saving the dataframe to a csv file
pieces_final.to_csv(dump_pieces_path)

# %% [markdown]
# # Isomap Embedding:
# **Warning** This takes a long time to run, especially for the multiple composers case! We have computed the embeddings and saved them in ./dump/, therefore the rest of the pipeline can be run without these cells.

# %%
# adding the albrecht key profile and the uniform distribution to the datapoints to compute a whole embedding
# The albrecht profile and uniform distribution will be used as landmarks to the visualisations
profile_transposed, labels = key_profile_uniform_add()

# %%
data_pts = get_pitchscapes_as_np_array(pieces_final)
embedding = Isomap(n_components=3, n_neighbors=10, metric=scipy.spatial.distance.jensenshannon)
X_transformed = embedding.fit_transform(data_pts)
landmarks = embedding.transform(profile_transposed)

# %%
np.save(dump_embedding_path, X_transformed)
np.save(dump_landmarks_path, landmarks)
np.save(dump_landmark_labels_path, labels)
